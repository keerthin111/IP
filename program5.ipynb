# %%
from skimage import io
import matplotlib.pyplot as plt
url='https://cdn.wionews.com/sites/default/files/styles/story_page/public/2022/03/11/246868-rainbow-coloured-fish.jpg'
image=io.imread(url)
plt.imshow(image)
plt.show()
